# %%
# creating an image
import cv2
import matplotlib.pyplot as plt

# load image
image_path = "./Kopitar.jpg" # use your own image path
img = cv2.imread(image_path)
# convert from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img), plt.title('Lost'), plt.xticks([]), plt.yticks([])
plt.show()
